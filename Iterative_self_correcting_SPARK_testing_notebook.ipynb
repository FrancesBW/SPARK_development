# %% [markdown]
# # Testing of the new SPARK optimisation
# * ## [Setup](#setup)
# * ## [From 1-n, the init==0 case](#iterative)
#     + ### [Running the algorithm and plotting output](#run_init_1)
# * ## From k-n, the init==1 case
# * ## All in one go, the init==2 case

# %% [markdown]
# <a id='setup'></a>
# ## Setup

# %%
import numpy as np
from astropy.io import fits
import astropy.table as pytabs
import matplotlib.pyplot as plt
import os

os.chdir('SPARK/SPARK/absorption/')
from absorption_nov import lbfgs_abs
os.chdir('../../../')

# %% [markdown]
# <a id='iterative'></a>
# ## From 1-n, the init==0 case
# <a id='run_init_1'></a>
# ### Running the algorithm and plotting output

# %%
path = ''
name = '3C225B'

cat = fits.getdata(path+"all_sponge_sources_table_tighter.fits")
data_s = pytabs.Table(cat)
idx_absline=np.where(data_s["NAMES"]==name)[0][0]
#we have to un-nan for some sources that we added nans to to make them fit in the table
nan_values=np.isnan(data_s[idx_absline]["VEL"])
numeric_values=[not i for i in nan_values]
v = data_s[idx_absline]["VEL"][numeric_values]
#correct velocities to model over
chiller_vel_idx=np.intersect1d(np.where(v>-100.),np.where(v<80.))

#initialise the reduced data
v = v[chiller_vel_idx]
Tb = data_s[idx_absline]["TB"][numeric_values][chiller_vel_idx]
tau = data_s[idx_absline]["TAU"][numeric_values][chiller_vel_idx]
rms_Tb=data_s[idx_absline]['SIG_TB'][numeric_values][chiller_vel_idx]
rms_tau=data_s[idx_absline]['SIG_TAU'][numeric_values][chiller_vel_idx]

#Channel spacing
dv = np.diff(v)[0]

#hdr
hdr=fits.Header()
hdr["CDELT3"] = dv
hdr["CRPIX3"] = 0
hdr["CRVAL3"] = v[0]*1.e3

#parameters                                                                                                                                                                                                                                                              
amp_fact_init = 2./3.
sig_init = 20.
iprint_init = -1
iprint = -1
maxiter_init = 15000
maxiter = 15000
corr_iter = 15

n_gauss = 7            #@param {type:"slider", min:3, max:24, step:3} 
fit_tol = 1.1          #@param {type:"slider", min:1, max:100, step:10}
pcc_lim_mu = 0.999           #@param {type:"slider", min:0, max:100, step:10}
pcc_lim_sig = 0.999          #@param {type:"slider", min:0, max:100, step:10}
lb_amp = 0.
ub_amp = np.max(Tb)
lb_mu = 1
ub_mu = len(tau)
lb_sig= 1
ub_sig = len(tau)/3

core = lbfgs_abs(Tb=Tb, tau=tau, hdr=hdr, rms_Tb=rms_Tb, rms_tau=rms_tau)

solution=core.run(n_gauss=n_gauss, 
                  lb_amp=lb_amp,
                  ub_amp=ub_amp,
                  lb_mu=lb_mu,
                  ub_mu=ub_mu,
                  lb_sig=lb_sig,
                  ub_sig=ub_sig, 
                  pcc_mu=pcc_lim_mu, 
                  pcc_sig=pcc_lim_sig, 
                  red_chi_sq_thres=fit_tol, 
                  amp_fact_init=amp_fact_init,
                  sig_init=sig_init,
                  maxiter=maxiter,
                  maxiter_init=maxiter_init, 
                  max_cor_iter=corr_iter, 
                  iprint=iprint,
                  iprint_init=iprint_init, 
                  init=0, 
                  prior=None)
# Out:
# The first gaussian is estimated as:
# [5.18606806e-01 6.03973661e+02 4.47742588e+01]
# Optimising for 1 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.18606806e-01 5.18606806e-01]
#  [6.03973661e+02 6.03973661e+02]
#  [4.47742588e+01 4.47742588e+01]]
# The J value of this guess is:. 3318504.050113622
# Parameters after the optimisation
# [[5.13913873e-01 5.84193278e-02]
#  [6.03705032e+02 6.05268675e+02]
#  [4.45169007e+01 4.04161879e+01]]
# J value 2412455.0730599435
# **********************************************
# ************************************
# The chi squared outputs: res, rms, dof, chi_sq
# [[ 1.58314623e-03  1.16229671e-50]
#  [-2.40431226e-03  1.68309427e-50]
#  [-1.29273582e-03  2.43575723e-50]
#  ...
#  [ 6.07391068e-04  1.68361878e-36]
#  [-1.17251997e-03  1.23193338e-36]
#  [-6.68612678e-04  9.00875570e-37]]
# [[0.00101518 0.00255307]
#  [0.00101618 0.00255307]
#  [0.0010159  0.00255307]
#  ...
#  [0.00101542 0.00256625]
#  [0.00101587 0.00256625]
#  [0.00101574 0.00256625]]
# 1115
# [[ 1.55948067e+00  4.55254195e-48]
#  [-2.36603602e+00  6.59242789e-48]
#  [-1.27250563e+00  9.54049586e-48]
#  ...
#  [ 5.98167089e-01  6.56062637e-34]
#  [-1.15420539e+00  4.80052533e-34]
#  [-6.58251115e-01  3.51047880e-34]]
# 4513798.642243566
# the max of the res for Tb is 0.46681824230233954
# the min of the rms for Tb is 0.0010151752816353725
# ************************************
# Calculated values are:
# [4048.249903357458, 279.0237626764847]
# [1. 1.]
# emission not fitted enough, current lambda_tb = 1.0
# This is iteration 0
# ammended lambda_tb = 1.6666666666666665
# absorption not fitted enough, current lambda_tau = 1.0
# ammended lambda_tau = 1.6666666666666665
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.13913873e-01 5.84193278e-02]
#  [6.03705032e+02 6.05268675e+02]
#  [4.45169007e+01 4.04161879e+01]]
# The J value of this guess is:. 4020758.4522692254
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 2 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.13913873e-01 5.84193278e-02]
#  [6.03705032e+02 6.05268675e+02]
#  [4.45169007e+01 4.04161879e+01]
#  [3.84135961e-01 7.85571917e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 5182236.52358097
# Parameters after the optimisation
# [[5.11101121e-01 0.00000000e+00]
#  [5.98885116e+02 6.04490342e+02]
#  [3.69100012e+01 3.94960068e+01]
#  [5.85428905e-01 3.46543744e-01]
#  [6.43043266e+02 6.44836859e+02]
#  [4.30633783e+00 9.82774518e+00]]
# J value 1769703.1881665168
# **********************************************
# ************************************
# The chi squared outputs: res, rms, dof, chi_sq
# [[ 0.00158315  0.        ]
#  [-0.00240431  0.        ]
#  [-0.00129274  0.        ]
#  ...
#  [ 0.00060739  0.        ]
#  [-0.00117252  0.        ]
#  [-0.00066861  0.        ]]
# [[0.00101518 0.00255307]
#  [0.00101618 0.00255307]
#  [0.0010159  0.00255307]
#  ...
#  [0.00101542 0.00256625]
#  [0.00101587 0.00256625]
#  [0.00101574 0.00256625]]
# 1112
# [[ 1.55948067  0.        ]
#  [-2.36603602  0.        ]
#  [-1.27250563  0.        ]
#  ...
#  [ 0.59816709  0.        ]
#  [-1.15420539  0.        ]
#  [-0.65825112  0.        ]]
# 3383145.2855901704
# the max of the res for Tb is 0.2591883379130751
# the min of the rms for Tb is 0.0010151752816353725
# ************************************
# Calculated values are:
# [3042.3968395595057, 140.53103683536511]
# [1. 1.]
# emission not fitted enough, current lambda_tb = 1.0
# This is iteration 0
# ammended lambda_tb = 1.6666666666666665
# absorption not fitted enough, current lambda_tau = 1.0
# ammended lambda_tau = 1.6666666666666665
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.11101121e-01 0.00000000e+00]
#  [5.98885116e+02 6.04490342e+02]
#  [3.69100012e+01 3.94960068e+01]
#  [5.85428905e-01 3.46543744e-01]
#  [6.43043266e+02 6.44836859e+02]
#  [4.30633783e+00 9.82774518e+00]]
# The J value of this guess is:. 2949513.98992643
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 3 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.11101121e-01 0.00000000e+00]
#  [5.98885116e+02 6.04490342e+02]
#  [3.69100012e+01 3.94960068e+01]
#  [5.85428905e-01 3.46543744e-01]
#  [6.43043266e+02 6.44836859e+02]
#  [4.30633783e+00 9.82774518e+00]
#  [4.38265216e-02 4.75109395e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 2346349.8156859027
# Parameters after the optimisation
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]]
# J value 1739259.1591415056
# **********************************************
# ************************************
# The chi squared outputs: res, rms, dof, chi_sq
# [[ 0.00158315  0.        ]
#  [-0.00240431  0.        ]
#  [-0.00129274  0.        ]
#  ...
#  [ 0.00060739  0.        ]
#  [-0.00117252  0.        ]
#  [-0.00066861  0.        ]]
# [[0.00101518 0.00255307]
#  [0.00101618 0.00255307]
#  [0.0010159  0.00255307]
#  ...
#  [0.00101542 0.00256625]
#  [0.00101587 0.00256625]
#  [0.00101574 0.00256625]]
# 1109
# [[ 1.55948067  0.        ]
#  [-2.36603602  0.        ]
#  [-1.27250563  0.        ]
#  ...
#  [ 0.59816709  0.        ]
#  [-1.15420539  0.        ]
#  [-0.65825112  0.        ]]
# 3385752.506812248
# the max of the res for Tb is 0.25918820556502864
# the min of the rms for Tb is 0.0010151752816353725
# ************************************
# Calculated values are:
# [3052.9779141679423, 83.64767335885224]
# [0.99953177 0.99348752]
# emission not fitted enough, current lambda_tb = 1.0
# This is iteration 0
# ammended lambda_tb = 1.6666666666666665
# absorption not fitted enough, current lambda_tau = 1.0
# ammended lambda_tau = 1.6666666666666665
# sig dont align enough, current lambda_sig = 1.0
# ammended lambda_sig = 1.6666666666666665
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]]
# The J value of this guess is:. 2898765.265174949
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 4 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]
#  [1.83231875e-02 3.49425669e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 2032406.5407800176
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 5 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]
#  [1.83231875e-02 3.49425669e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.59188206e-01 2.00362608e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 1222989.5257113944
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 6 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]
#  [1.83231875e-02 3.49425669e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.59188206e-01 2.00362608e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.19474828e-01 3.50869665e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 606238.1658028862
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 7 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.19147793e-01 0.00000000e+00]
#  [5.96523230e+02 6.04490340e+02]
#  [3.80545951e+01 3.94957294e+01]
#  [4.85350458e-01 4.72566261e-01]
#  [6.43452681e+02 6.44723383e+02]
#  [3.94555215e+00 6.83773514e+00]
#  [1.99811066e-02 0.00000000e+00]
#  [6.45082121e+02 6.44674393e+02]
#  [1.99094750e+01 1.88606194e+01]
#  [1.83231875e-02 3.49425669e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.59188206e-01 2.00362608e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.19474828e-01 3.50869665e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [1.10743492e-01 4.91584762e-01]
#  [6.40000000e+02 6.40000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 2002809.3105576257
# Parameters after the optimisation
# [[4.98248391e-01 8.24380279e-03]
#  [5.96255184e+02 6.04484862e+02]
#  [3.98818859e+01 3.94939053e+01]
#  [5.71061035e-01 8.06075041e-01]
#  [6.42754625e+02 6.45126596e+02]
#  [4.15358134e+00 3.28209889e+00]
#  [0.00000000e+00 0.00000000e+00]
#  [6.45360222e+02 6.44674526e+02]
#  [1.99663687e+01 1.88615284e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [6.45076081e+02 6.45175199e+02]
#  [1.99716698e+01 1.95063666e+01]
#  [2.33737877e-01 2.36951098e-02]
#  [3.86367331e+02 3.88881890e+02]
#  [1.56213278e+01 1.99661924e+01]
#  [2.12527698e-01 2.07742011e-02]
#  [4.48793884e+02 4.46064723e+02]
#  [2.15927579e+01 1.99112684e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [6.40055304e+02 6.39491862e+02]
#  [1.96685761e+01 1.95040334e+01]]
# J value 129394.69642705216
# **********************************************
# ************************************
# The chi squared outputs: res, rms, dof, chi_sq
# [[ 1.58314623e-03  1.11107601e-53]
#  [-2.40431226e-03  1.63649401e-53]
#  [-1.29273582e-03  2.40883269e-53]
#  ...
#  [ 6.07391068e-04  4.28984177e-39]
#  [-1.17251997e-03  3.09141043e-39]
#  [-6.68612678e-04  2.22635095e-39]]
# [[0.00101518 0.00255307]
#  [0.00101618 0.00255307]
#  [0.0010159  0.00255307]
#  ...
#  [0.00101542 0.00256625]
#  [0.00101587 0.00256625]
#  [0.00101574 0.00256625]]
# 1097
# [[ 1.55948067e+00  4.35191812e-51]
#  [-2.36603602e+00  6.40990166e-51]
#  [-1.27250563e+00  9.43503645e-51]
#  ...
#  [ 5.98167089e-01  1.67164024e-36]
#  [-1.15420539e+00  1.20464259e-36]
#  [-6.58251115e-01  8.67551311e-37]]
# 254077.3023668623
# the max of the res for Tb is 0.05915518049295804
# the min of the rms for Tb is 0.0010151752816353725
# ************************************
# Calculated values are:
# [231.61103223961925, 4.295313569775983]
# [0.9994687  0.98191136]
# emission not fitted enough, current lambda_tb = 1.0
# This is iteration 0
# ammended lambda_tb = 1.6666666666666665
# absorption not fitted enough, current lambda_tau = 1.0
# ammended lambda_tau = 1.6666666666666665
# sig dont align enough, current lambda_sig = 1.0
# ammended lambda_sig = 1.6666666666666665
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[4.98248391e-01 8.24380279e-03]
#  [5.96255184e+02 6.04484862e+02]
#  [3.98818859e+01 3.94939053e+01]
#  [5.71061035e-01 8.06075041e-01]
#  [6.42754625e+02 6.45126596e+02]
#  [4.15358134e+00 3.28209889e+00]
#  [0.00000000e+00 0.00000000e+00]
#  [6.45360222e+02 6.44674526e+02]
#  [1.99663687e+01 1.88615284e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [6.45076081e+02 6.45175199e+02]
#  [1.99716698e+01 1.95063666e+01]
#  [2.33737877e-01 2.36951098e-02]
#  [3.86367331e+02 3.88881890e+02]
#  [1.56213278e+01 1.99661924e+01]
#  [2.12527698e-01 2.07742011e-02]
#  [4.48793884e+02 4.46064723e+02]
#  [2.15927579e+01 1.99112684e+01]
#  [0.00000000e+00 0.00000000e+00]
#  [6.40055304e+02 6.39491862e+02]
#  [1.96685761e+01 1.95040334e+01]]
# The J value of this guess is:. 215657.82728329182
# No improvement found, exiting correction stage

# %%
ub_sig
# Out:
# 372.6666666666667

# %%
cube = np.moveaxis(np.array([Tb,tau]),0,1)
params = np.reshape(solution, (3*n_gauss, cube.shape[1]))
vfield_Tb = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,0])
vfield_tau = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,1])

model_cube = core.model(params, cube, n_gauss)

# %%
plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
plt.plot(vfield_Tb, vfield_tau, "+b")
plt.xlabel(r"v$_{\rm Tb}$ [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"v$_{\rm tau}$ [km s$^{-1}$]", fontsize=16)

plt.subplot(1,2,2)
plt.plot(params[:,0][2::3]*dv, params[:,1][2::3]*dv, "+r")
plt.xlabel(r"$\sigma_{\rm Tb}$ [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"$\sigma_{\rm tau}$ [km s$^{-1}$]", fontsize=16)
plt.savefig("correlation.png", format='png', bbox_inches='tight', 
  pad_inches=0.02)

plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(vfield_Tb, params[:,0][2::3]*dv, "+g")
plt.plot(vfield_tau, params[:,1][2::3]*dv, "+m")
plt.xlabel(r"v [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"$\sigma$ [km s$^{-1}$]", fontsize=16)
#plt.savefig("sigma_v.png", format='png', bbox_inches='tight', pad_inches=0.02)
plt.show()

# %%
#Plot    
pvalues = np.logspace(-1, 0, n_gauss)
pmin = pvalues[0]
pmax = pvalues[-1]


def norm(pval):
    return (pval - pmin) / float(pmax - pmin)

fig, [ax1, ax2, ax3, ax4] = plt.subplots(4, 1, sharex=True, figsize=(20,16),gridspec_kw={'height_ratios': [4,1,1,4]})
fig.subplots_adjust(hspace=0.)
x = np.arange(cube.shape[0])
ax1.step(v, cube[:,0], color='cornflowerblue', linewidth=2.)
ax1.plot(v, model_cube[:,0], color='k')
ax2.plot(v, model_cube[:,0] - cube[:,0], color='k')
ax2.fill_between(v, -3.*rms_Tb, 3.*rms_Tb, facecolor='lightgray', color='lightgray')
ax3.plot(v, -model_cube[:,1] + cube[:,1], color='k')
ax3.fill_between(v, -3.*rms_tau, 3.*rms_tau, facecolor='lightgray', color='lightgray')
ax4.step(v, -cube[:,1], color='cornflowerblue', linewidth=2.)
ax4.plot(v, -model_cube[:,1], color='k')
ax1.set_ylabel(r'T$_{B}$ [K]', fontsize=16)
ax2.set_ylabel(r'$T_B$ res [K]', fontsize=12)
ax3.set_ylabel(r"$\tau$ res", fontsize=12)
ax4.set_ylabel(r'$- \tau$', fontsize=16)
ax4.set_xlabel(r'v [km s$^{-1}$]', fontsize=16)
#plt.savefig("3C041A_result_7_with_adjustment.png", format='png', bbox_inches='tight', 
  #pad_inches=0.02)
plt.show()

# %%
solution[2::3,0]
# Out:
# array([30.        ,  7.16116706,  1.95734307,  1.82475783,  1.845648  ,
#         2.        ,  2.        ])

# %%
solution[2::3,1]
# Out:
# array([29.92645617,  2.48468916,  1.76709984,  1.989963  ,  1.99958855,
#         2.        ,  2.        ])

# %%
def pcc(x,y):
    mean_x=np.mean(x)
    mean_y=np.mean(y)
    numerator=np.sum((x-mean_x)*(y-mean_y))
    denominator=np.sqrt(np.sum((x-mean_x)**2)*np.sum((y-mean_y)**2))
    return numerator/denominator

# %%
pcc(solution[2::3,0],solution[2::3,1])
# Out:
# 0.9857423933192863

# %%
plt.scatter(solution[2::3,0],solution[2::3,1])
plt.show()
