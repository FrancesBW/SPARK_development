# %% [markdown]
# # Testing of the new SPARK optimisation
# * ## [Setup](#setup)
# * ## [From 1-n, the init==0 case](#iterative)
#     + ### [Running the algorithm and plotting output](#run_init_1)
# * ## From k-n, the init==1 case
# * ## [All in one go, the init==2 case](#init2)

# %% [markdown]
# <a id='setup'></a>
# ## Setup

# %%
import numpy as np
from astropy.io import fits
import astropy.table as pytabs
import matplotlib.pyplot as plt
import os

os.chdir('SPARK/SPARK/absorption/')
from absorption_nov import lbfgs_abs
os.chdir('../../../')

# %% [markdown]
# <a id='iterative'></a>
# ## From 1-n, the init==0 case
# <a id='run_init_1'></a>
# ### Running the algorithm and plotting output

# %%
path = ''
name = '3C225A'

cat = fits.getdata(path+"all_sponge_sources_table_tighter.fits")
data_s = pytabs.Table(cat)
idx_absline=np.where(data_s["NAMES"]==name)[0][0]
#we have to un-nan for some sources that we added nans to to make them fit in the table
nan_values=np.isnan(data_s[idx_absline]["VEL"])
numeric_values=[not i for i in nan_values]
v = data_s[idx_absline]["VEL"][numeric_values]
#correct velocities to model over
chiller_vel_idx=np.intersect1d(np.where(v>-100.),np.where(v<80.))

#initialise the reduced data
v = v[chiller_vel_idx]
Tb = data_s[idx_absline]["TB"][numeric_values][chiller_vel_idx]
tau = data_s[idx_absline]["TAU"][numeric_values][chiller_vel_idx]
rms_Tb=data_s[idx_absline]['SIG_TB'][numeric_values][chiller_vel_idx]
rms_tau=data_s[idx_absline]['SIG_TAU'][numeric_values][chiller_vel_idx]

#Channel spacing
dv = np.diff(v)[0]

#hdr
hdr=fits.Header()
hdr["CDELT3"] = dv
hdr["CRPIX3"] = 0
hdr["CRVAL3"] = v[0]*1.e3

#parameters                                                                                                                                                                                                                                                              
amp_fact_init = 2./3.
sig_init = 20.
iprint_init = -1
iprint = -1
maxiter_init = 15000
maxiter = 15000
corr_iter = 15

n_gauss = 7            #@param {type:"slider", min:3, max:24, step:3} 
fit_tol = 1.1          #@param {type:"slider", min:1, max:100, step:10}
pcc_lim_mu = 5.          #@param {type:"slider", min:0, max:100, step:10}
pcc_lim_sig = 3.          #@param {type:"slider", min:0, max:100, step:10}
lb_amp = 0.
ub_amp = np.max(Tb)
lb_mu = 1
ub_mu = len(tau)
lb_sig= 1
ub_sig = len(tau)/3

core = lbfgs_abs(Tb=Tb, tau=tau, hdr=hdr, rms_Tb=rms_Tb, rms_tau=rms_tau)

solution=core.run(n_gauss=n_gauss, 
                  lb_amp=lb_amp,
                  ub_amp=ub_amp,
                  lb_mu=lb_mu,
                  ub_mu=ub_mu,
                  lb_sig=lb_sig,
                  ub_sig=ub_sig, 
                  pcc_mu=pcc_lim_mu, 
                  pcc_sig=pcc_lim_sig, 
                  red_chi_sq_thres=fit_tol, 
                  amp_fact_init=amp_fact_init,
                  sig_init=sig_init,
                  maxiter=maxiter,
                  maxiter_init=maxiter_init, 
                  max_cor_iter=corr_iter, 
                  iprint=iprint,
                  iprint_init=iprint_init, 
                  init=0, 
                  prior=None)
# Out:
# Optimising for 1 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.41287778e-01 5.41287778e-01]
#  [6.03973651e+02 6.03973651e+02]
#  [4.47742727e+01 4.47742727e+01]]
# The J value of this guess is:. 6110405.020623716
# Parameters after the optimisation
# [[5.41127620e-01 7.03585634e-02]
#  [6.03293695e+02 6.10183758e+02]
#  [4.41199615e+01 3.43637540e+01]]
# J value 2818524.583577769
# **********************************************
# Calculated values are:
# [4047.214261108166, 1008.4351721896132]
# [[6.89006289]
#  [9.75620751]]
# emission not fitted enough, current lambda_tb = 0.0002470835333848103
# This is iteration 0
# ammended lambda_tb = 0.0004941670667696206
# absorption not fitted enough, current lambda_tau = 0.0009916353847800668
# ammended lambda_tau = 0.0019832707695601336
# mu dont align enough, current lambda_mu = 7666.7482077652385
# ammended lambda_mu = 15333.496415530477
# sig dont align enough, current lambda_sig = 20.450700623911725
# ammended lambda_sig = 40.90140124782345
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.41127620e-01 7.03585634e-02]
#  [6.03293695e+02 6.10183758e+02]
#  [4.41199615e+01 3.43637540e+01]]
# The J value of this guess is:. 2232.0
# Parameters after the optimisation
# [[5.41778971e-01 6.56175448e-02]
#  [6.03371279e+02 6.10109425e+02]
#  [4.40781372e+01 3.44190540e+01]]
# J value 2231.8815296981047
# **********************************************
# Calculated values are:
# [4047.68162520924, 1008.2674726170515]
# [[6.73814611]
#  [9.65908325]]
# emission not fitted enough, current lambda_tb = 0.0002470550039736157
# This is iteration 1
# ammended lambda_tb = 0.0004941100079472314
# absorption not fitted enough, current lambda_tau = 0.0009918003180291114
# ammended lambda_tau = 0.001983600636058223
# mu dont align enough, current lambda_mu = 8018.412962166251
# ammended lambda_mu = 16036.825924332503
# sig dont align enough, current lambda_sig = 20.824503054520683
# ammended lambda_sig = 41.649006109041366
# pushed 2 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.41778971e-01 6.56175448e-02]
#  [6.03371279e+02 6.10109425e+02]
#  [4.40781372e+01 3.44190540e+01]]
# The J value of this guess is:. 2232.0
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 2 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.41778971e-01 6.56175448e-02]
#  [6.03371279e+02 6.10109425e+02]
#  [4.40781372e+01 3.44190540e+01]
#  [4.02930236e-01 8.18284045e-01]
#  [6.45000000e+02 6.45000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 7867072.525412387
# Parameters after the optimisation
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]]
# J value 1657301.8607076209
# **********************************************
# Calculated values are:
# [2956.4353606010477, 24.32329585460052]
# [[11.61190724  2.42113882]
#  [ 8.87029321  0.88731682]]
# emission not fitted enough, current lambda_tb = 0.00033824517637913063
# This is iteration 0
# ammended lambda_tb = 0.0006764903527582613
# absorption not fitted enough, current lambda_tau = 0.0411128494254145
# ammended lambda_tau = 0.082225698850829
# mu dont align enough, current lambda_mu = 2545.2043157324265
# ammended lambda_mu = 5090.408631464853
# sig dont align enough, current lambda_sig = 10.52147976269068
# ammended lambda_sig = 21.04295952538136
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]]
# The J value of this guess is:. 2226.0
# Parameters after the optimisation
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]]
# J value 2226.0
# **********************************************
# Calculated values are:
# [2956.4353606010477, 24.323295854600524]
# [[11.61190724  2.42113882]
#  [ 8.87029321  0.88731682]]
# emission not fitted enough, current lambda_tb = 0.00033824517637913063
# This is iteration 1
# ammended lambda_tb = 0.0006764903527582613
# absorption not fitted enough, current lambda_tau = 0.0411128494254145
# ammended lambda_tau = 0.082225698850829
# mu dont align enough, current lambda_mu = 2545.2043157324265
# ammended lambda_mu = 5090.408631464853
# sig dont align enough, current lambda_sig = 10.52147976269071
# ammended lambda_sig = 21.04295952538142
# pushed 2 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]]
# The J value of this guess is:. 2226.0
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 3 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]
#  [2.70522409e-01 1.94282829e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 845170.3557327559
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 4 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]
#  [2.70522409e-01 1.94282829e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.28673123e-01 3.28508548e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 236538.51611670724
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 5 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]
#  [2.70522409e-01 1.94282829e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.28673123e-01 3.28508548e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [6.74561643e-02 2.99610158e-03]
#  [5.93000000e+02 5.93000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 259015.1726792997
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 6 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]
#  [2.70522409e-01 1.94282829e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.28673123e-01 3.28508548e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [6.74561643e-02 2.99610158e-03]
#  [5.93000000e+02 5.93000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [5.40709999e-02 1.95964465e-03]
#  [4.91000000e+02 4.91000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 235587.0674678239
# No improvement found, exiting correction stage
# a loop in the while
# Optimising for 7 gaussians
# **********************************************
# Parameters prior to optimisation lbfgs
# [[5.14677073e-01 9.97886514e-03]
#  [5.96698880e+02 6.08310788e+02]
#  [4.10886298e+01 3.22183366e+01]
#  [5.88871881e-01 8.42187591e-01]
#  [6.42626273e+02 6.45047411e+02]
#  [4.03164878e+00 3.14433196e+00]
#  [2.70522409e-01 1.94282829e-02]
#  [3.89000000e+02 3.89000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [2.28673123e-01 3.28508548e-02]
#  [4.46000000e+02 4.46000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [6.74561643e-02 2.99610158e-03]
#  [5.93000000e+02 5.93000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [5.40709999e-02 1.95964465e-03]
#  [4.91000000e+02 4.91000000e+02]
#  [2.00000000e+01 2.00000000e+01]
#  [3.63174615e-02 3.89332487e-02]
#  [3.71000000e+02 3.71000000e+02]
#  [2.00000000e+01 2.00000000e+01]]
# The J value of this guess is:. 308671.9644034037
# Parameters after the optimisation
# [[3.44247148e-01 1.51036178e-03]
#  [5.99539272e+02 6.08307558e+02]
#  [4.70590767e+01 3.22634816e+01]
#  [6.20751194e-01 8.48849884e-01]
#  [6.42452135e+02 6.45032214e+02]
#  [4.37601301e+00 3.13874899e+00]
#  [2.33394114e-01 5.68664071e-03]
#  [3.87139738e+02 3.88893858e+02]
#  [1.17832770e+01 1.96618784e+01]
#  [2.19342663e-01 2.16625715e-02]
#  [4.41856873e+02 4.46536234e+02]
#  [1.98775203e+01 1.92086850e+01]
#  [2.30143046e-01 1.14232290e-02]
#  [5.92659539e+02 5.92912723e+02]
#  [1.96688908e+01 1.99954852e+01]
#  [5.66862275e-02 0.00000000e+00]
#  [4.90954309e+02 4.91000350e+02]
#  [1.95570400e+01 1.99970145e+01]
#  [4.27256645e-02 2.11053350e-02]
#  [3.70789121e+02 3.71406270e+02]
#  [2.04991743e+01 1.92512920e+01]]
# J value 34560.93096260454
# **********************************************
# Calculated values are:
# [54.06023313263106, 8.94909238111658]
# [[ 8.76828567  2.58007947  1.75411935  4.67936074  0.25318335  0.04604091
#    0.61714992]
#  [14.79559509  1.23726401  7.87860139  0.66883535  0.32659443  0.43997444
#    1.24788238]]
# emission not fitted enough, current lambda_tb = 0.01849788545207724
# This is iteration 0
# ammended lambda_tb = 0.03699577090415448
# absorption not fitted enough, current lambda_tau = 0.11174317544314251
# ammended lambda_tau = 0.22348635088628502
# mu dont align enough, current lambda_mu = 2734.751273071178
# ammended lambda_mu = 5469.502546142356
# sig dont align enough, current lambda_sig = 1.583604088014258
# ammended lambda_sig = 3.167208176028516
# pushed 1 time(s)
# **********************************************
# Parameters prior to optimisation lbfgs
# [[3.44247148e-01 1.51036178e-03]
#  [5.99539272e+02 6.08307558e+02]
#  [4.70590767e+01 3.22634816e+01]
#  [6.20751194e-01 8.48849884e-01]
#  [6.42452135e+02 6.45032214e+02]
#  [4.37601301e+00 3.13874899e+00]
#  [2.33394114e-01 5.68664071e-03]
#  [3.87139738e+02 3.88893858e+02]
#  [1.17832770e+01 1.96618784e+01]
#  [2.19342663e-01 2.16625715e-02]
#  [4.41856873e+02 4.46536234e+02]
#  [1.98775203e+01 1.92086850e+01]
#  [2.30143046e-01 1.14232290e-02]
#  [5.92659539e+02 5.92912723e+02]
#  [1.96688908e+01 1.99954852e+01]
#  [5.66862275e-02 0.00000000e+00]
#  [4.90954309e+02 4.91000350e+02]
#  [1.95570400e+01 1.99970145e+01]
#  [4.27256645e-02 2.11053350e-02]
#  [3.70789121e+02 3.71406270e+02]
#  [2.04991743e+01 1.92512920e+01]]
# The J value of this guess is:. 2196.0
# No improvement found, exiting correction stage

# %%
ub_sig
# Out:
# 372.6666666666667

# %%
cube = np.moveaxis(np.array([Tb,tau]),0,1)
params = np.reshape(solution, (3*n_gauss, cube.shape[1]))
vfield_Tb = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,0])
vfield_tau = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,1])

model_cube = core.model(params, cube, n_gauss)

# %%
plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
plt.plot(vfield_Tb, vfield_tau, "+b")
plt.xlabel(r"v$_{\rm Tb}$ [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"v$_{\rm tau}$ [km s$^{-1}$]", fontsize=16)

plt.subplot(1,2,2)
plt.plot(params[:,0][2::3]*dv, params[:,1][2::3]*dv, "+r")
plt.xlabel(r"$\sigma_{\rm Tb}$ [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"$\sigma_{\rm tau}$ [km s$^{-1}$]", fontsize=16)
plt.savefig("correlation.png", format='png', bbox_inches='tight', 
  pad_inches=0.02)

plt.figure(figsize=(8,6))
plt.subplot(1,1,1)
plt.plot(vfield_Tb, params[:,0][2::3]*dv, "+g")
plt.plot(vfield_tau, params[:,1][2::3]*dv, "+m")
plt.xlabel(r"v [km s$^{-1}$]", fontsize=16)
plt.ylabel(r"$\sigma$ [km s$^{-1}$]", fontsize=16)
#plt.savefig("sigma_v.png", format='png', bbox_inches='tight', pad_inches=0.02)
plt.show()

# %%
## Plot    
pvalues = np.logspace(-1, 0, n_gauss)
pmin = pvalues[0]
pmax = pvalues[-1]


def norm(pval):
    return (pval - pmin) / float(pmax - pmin)

fig, [ax1, ax2, ax3, ax4] = plt.subplots(4, 1, sharex=True, figsize=(20,16),gridspec_kw={'height_ratios': [4,1,1,4]})
fig.subplots_adjust(hspace=0.)
x = np.arange(cube.shape[0])
ax1.step(v, cube[:,0], color='cornflowerblue', linewidth=2.)
ax1.plot(v, model_cube[:,0], color='k')
ax2.plot(v, model_cube[:,0] - cube[:,0], color='k')
ax2.fill_between(v, -3.*rms_Tb, 3.*rms_Tb, facecolor='lightgray', color='lightgray')
ax3.plot(v, -model_cube[:,1] + cube[:,1], color='k')
ax3.fill_between(v, -3.*rms_tau, 3.*rms_tau, facecolor='lightgray', color='lightgray')
ax4.step(v, -cube[:,1], color='cornflowerblue', linewidth=2.)
ax4.plot(v, -model_cube[:,1], color='k')
ax1.set_ylabel(r'T$_{B}$ [K]', fontsize=16)
ax2.set_ylabel(r'$T_B$ res [K]', fontsize=12)
ax3.set_ylabel(r"$\tau$ res", fontsize=12)
ax4.set_ylabel(r'$- \tau$', fontsize=16)
ax4.set_xlabel(r'v [km s$^{-1}$]', fontsize=16)
#plt.savefig("3C041A_result_7_with_adjustment.png", format='png', bbox_inches='tight', 
  #pad_inches=0.02)
plt.show()

# %%
solution[2::3,0]
# Out:
# array([30.        ,  7.16116706,  1.95734307,  1.82475783,  1.845648  ,
#         2.        ,  2.        ])

# %%
solution[2::3,1]
# Out:
# array([29.92645617,  2.48468916,  1.76709984,  1.989963  ,  1.99958855,
#         2.        ,  2.        ])

# %%
def pcc(x,y):
    mean_x=np.mean(x)
    mean_y=np.mean(y)
    numerator=np.sum((x-mean_x)*(y-mean_y))
    denominator=np.sqrt(np.sum((x-mean_x)**2)*np.sum((y-mean_y)**2))
    return numerator/denominator

# %%
pcc(solution[2::3,0],solution[2::3,1])
# Out:
# 0.9857423933192863

# %%
plt.scatter(solution[2::3,0],solution[2::3,1])
plt.show()

# %% [markdown]
# <a id='init2'></a>
# ## All in one go, the init==2 case:

# %%
path = ''
name = '3C225A'

cat = fits.getdata(path+"all_sponge_sources_table_tighter.fits")
data_s = pytabs.Table(cat)
idx_absline=np.where(data_s["NAMES"]==name)[0][0]
#we have to un-nan for some sources that we added nans to to make them fit in the table
nan_values=np.isnan(data_s[idx_absline]["VEL"])
numeric_values=[not i for i in nan_values]
v = data_s[idx_absline]["VEL"][numeric_values]
#correct velocities to model over
chiller_vel_idx=np.intersect1d(np.where(v>-100.),np.where(v<80.))

#initialise the reduced data
v = v[chiller_vel_idx]
Tb = data_s[idx_absline]["TB"][numeric_values][chiller_vel_idx]
tau = data_s[idx_absline]["TAU"][numeric_values][chiller_vel_idx]
rms_Tb=data_s[idx_absline]['SIG_TB'][numeric_values][chiller_vel_idx]
rms_tau=data_s[idx_absline]['SIG_TAU'][numeric_values][chiller_vel_idx]

#Channel spacing
dv = np.diff(v)[0]

#hdr
hdr=fits.Header()
hdr["CDELT3"] = dv
hdr["CRPIX3"] = 0
hdr["CRVAL3"] = v[0]*1.e3

#parameters                                                                                                                                                                                                                                                              
amp_fact_init = 2./3.
sig_init = 20.
iprint_init = -1
iprint = -1
maxiter_init = 15000
maxiter = 15000
corr_iter = 15

n_gauss = 7            #@param {type:"slider", min:3, max:24, step:3} 
fit_tol = 1.1          #@param {type:"slider", min:1, max:100, step:10}
pcc_lim_mu = 5.          #@param {type:"slider", min:0, max:100, step:10}
pcc_lim_sig = 3.          #@param {type:"slider", min:0, max:100, step:10}
lb_amp = 0.
ub_amp = np.max(Tb)
lb_mu = 1
ub_mu = len(tau)
lb_sig= 1
ub_sig = len(tau)/3

core = lbfgs_abs(Tb=Tb, tau=tau, hdr=hdr, rms_Tb=rms_Tb, rms_tau=rms_tau)

solution=core.run(n_gauss=n_gauss, 
                  lb_amp=lb_amp,
                  ub_amp=ub_amp,
                  lb_mu=lb_mu,
                  ub_mu=ub_mu,
                  lb_sig=lb_sig,
                  ub_sig=ub_sig, 
                  pcc_mu=pcc_lim_mu, 
                  pcc_sig=pcc_lim_sig, 
                  red_chi_sq_thres=fit_tol, 
                  amp_fact_init=amp_fact_init,
                  sig_init=sig_init,
                  maxiter=maxiter,
                  maxiter_init=maxiter_init, 
                  max_cor_iter=corr_iter, 
                  iprint=iprint,
                  iprint_init=iprint_init, 
                  init=2, 
                  prior=None)

# %%
cube = np.moveaxis(np.array([Tb,tau]),0,1)
params = np.reshape(solution, (3*n_gauss, cube.shape[1]))
vfield_Tb = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,0])
vfield_tau = core.mean2vel(hdr["CRVAL3"]*1.e-3, hdr["CDELT3"], hdr["CRPIX3"], 
                            params[1::3,1])

model_cube = core.model(params, cube, n_gauss)

# %%
## Plot    
pvalues = np.logspace(-1, 0, n_gauss)
pmin = pvalues[0]
pmax = pvalues[-1]


def norm(pval):
    return (pval - pmin) / float(pmax - pmin)

fig, [ax1, ax2, ax3, ax4] = plt.subplots(4, 1, sharex=True, figsize=(20,16),gridspec_kw={'height_ratios': [4,1,1,4]})
fig.subplots_adjust(hspace=0.)
x = np.arange(cube.shape[0])
ax1.step(v, cube[:,0], color='cornflowerblue', linewidth=2.)
ax1.plot(v, model_cube[:,0], color='k')
ax2.plot(v, model_cube[:,0] - cube[:,0], color='k')
ax2.fill_between(v, -3.*rms_Tb, 3.*rms_Tb, facecolor='lightgray', color='lightgray')
ax3.plot(v, -model_cube[:,1] + cube[:,1], color='k')
ax3.fill_between(v, -3.*rms_tau, 3.*rms_tau, facecolor='lightgray', color='lightgray')
ax4.step(v, -cube[:,1], color='cornflowerblue', linewidth=2.)
ax4.plot(v, -model_cube[:,1], color='k')
ax1.set_ylabel(r'T$_{B}$ [K]', fontsize=16)
ax2.set_ylabel(r'$T_B$ res [K]', fontsize=12)
ax3.set_ylabel(r"$\tau$ res", fontsize=12)
ax4.set_ylabel(r'$- \tau$', fontsize=16)
ax4.set_xlabel(r'v [km s$^{-1}$]', fontsize=16)
#plt.savefig("3C041A_result_7_with_adjustment.png", format='png', bbox_inches='tight', 
  #pad_inches=0.02)
plt.show()

# %%
params
# Out:
# array([[7.54302352e+00, 7.54302352e+00],
#        [5.97072666e+02, 5.97072666e+02],
#        [3.82239891e+01, 3.82239891e+01],
#        [6.00642084e-01, 6.00642084e-01],
#        [6.42657809e+02, 6.42657809e+02],
#        [4.16293440e+00, 4.16293440e+00],
#        [2.79059873e+00, 2.79059873e+00],
#        [4.45851477e+02, 4.45851477e+02],
#        [3.19168259e+01, 3.19168259e+01],
#        [2.35645533e-01, 2.35645533e-01],
#        [3.84112653e+02, 3.84112653e+02],
#        [1.18222758e+01, 1.18222758e+01],
#        [1.21074734e+01, 1.21074734e+01],
#        [6.45038870e+02, 6.45038870e+02],
#        [3.13283990e+00, 3.13283990e+00],
#        [3.99214080e-02, 3.99214080e-02],
#        [3.75108446e+02, 3.75108446e+02],
#        [1.02582679e+01, 1.02582679e+01],
#        [6.94386971e-01, 6.94386971e-01],
#        [4.51649208e+02, 4.51649208e+02],
#        [6.60459488e+00, 6.60459488e+00]])
